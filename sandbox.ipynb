# %%
using Gadfly
plot(y=[1,2,3])

# %%
p1 = plot([sin,cos], 0, 2pi)
p2 = plot((x,y)->sin(x)+cos(y), 0, 2pi, 0, 2pi)
p3 = spy(ones(33)*sin.(0:(pi/16):2pi)' + cos.(0:(pi/16):2pi)*ones(33)')
hstack(p1,p2,p3)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Int64},Measures.Length{:cy,Int64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0cx, 0cy), (1.0w, 1.0h)), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.6666666666666666w, 0.0h), (0.3333333333333333w, 1.0h)), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Add{Measures.Add{Measures.Length{:w,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}},Measures.Add{Measures.Add{Measures.Length{:h,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}}}}((5.0mm, 5.0mm), (1.0w + -5.0mm + -5.0mm, 1.0h + -5.0mm + -5.0mm)), nothing, nothing, nothing, List([Compose.Table(Array{Compose.Context,1}[[Context(AdhocContainerPromise), Context(AdhocContainerPromise)] [Context(AdhocContainerPromise)] [Context(Context(Context(Context(Context(R,svga,svgc(geometry),s,f)),svgc(plotpanel))),Context(Context(Context(T,svgc(text_box),f),fo,svgc(guide crosshair)),Context(Context(Context(R,f),Context(T,f,fsz,fnt),svgc(text_box)),fo,svgc(guide helpscreen)),Context(Context(T,jsc,svgc(text_box),f),fo,svgc(guide questionmark))),Context(Context(Context(L,jsc,jsc,svga,svgc(guide ygridlines xfixed),sd,lw,s,v),Context(L,svgc(guide ygridlines xfixed),sd,lw,s)),Context(Context(L,jsc,jsc,svga,svgc(guide xgridlines yfixed),sd,lw,s,v),Context(L,svgc(guide xgridlines yfixed),sd,lw,s)),Context(R,svga,fo,f,s,svgc(guide background))),jsc)] [Context(Context(T,fsz,fnt,f),Context(Context(L,s,lw),R,svga,s,f),Context(Context(T,f,fsz,fnt,s)),svgc(guide colorkey))]; [] [] [Context(AdhocContainerPromise), Context(AdhocContainerPromise)] []; [] [] [Context(AdhocContainerPromise), Context(AdhocContainerPromise)] []], 3:3, 1:1, nothing, nothing, 1.0, Any[], Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 0.5, 33.0, 33.0, 2.0mm, 2.0mm, 2.0mm, 2.0mm), 0, false, false)]), List([]), List([Compose.Property{Compose.JSIncludePrimitive}(Compose.JSIncludePrimitive[JSIncludePrimitive("/Users/tarikz/.julia/packages/Gadfly/ew1SM/src/gadfly.js", ("Gadfly", "Gadfly"))]), Compose.Property{Compose.SVGClassPrimitive}(Compose.SVGClassPrimitive[SVGClassPrimitive("plotroot xscalable yscalable")])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol(""))]), List([]), List([]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.3333333333333333w, 0.0h), (0.3333333333333333w, 1.0h)), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Add{Measures.Add{Measures.Length{:w,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}},Measures.Add{Measures.Add{Measures.Length{:h,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}}}}((5.0mm, 5.0mm), (1.0w + -5.0mm + -5.0mm, 1.0h + -5.0mm + -5.0mm)), nothing, nothing, nothing, List([Compose.Table(Array{Compose.Context,1}[[Context(AdhocContainerPromise), Context(AdhocContainerPromise)] [Context(AdhocContainerPromise)] [Context(Context(Context(Context(Context(Context(L,svgc(color_...),sd,s),lw,f,svgc(geometry))),svgc(plotpanel))),Context(Context(Context(T,svgc(text_box),f),fo,svgc(guide crosshair)),Context(Context(Context(R,f),Context(T,f,fsz,fnt),svgc(text_box)),fo,svgc(guide helpscreen)),Context(Context(T,jsc,svgc(text_box),f),fo,svgc(guide questionmark))),Context(Context(Context(L,jsc,jsc,svga,svgc(guide ygridlines xfixed),sd,lw,s,v),Context(L,svgc(guide ygridlines xfixed),sd,lw,s)),Context(Context(L,jsc,jsc,svga,svgc(guide xgridlines yfixed),sd,lw,s,v),Context(L,svgc(guide xgridlines yfixe ...

# %%
using RDatasets

# %%
births = RDatasets.dataset("HistData", "Arbuthnot")[[:Year, :Males, :Females]]
# Out:
# 82×3 DataFrame
# │ Row │ Year   │ Males  │ Females │
# │     │ Int64⍰ │ Int64⍰ │ Int64⍰  │
# ├─────┼────────┼────────┼─────────┤
# │ 1   │ 1629   │ 5218   │ 4683    │
# │ 2   │ 1630   │ 4858   │ 4457    │
# │ 3   │ 1631   │ 4422   │ 4102    │
# │ 4   │ 1632   │ 4994   │ 4590    │
# │ 5   │ 1633   │ 5158   │ 4839    │
# │ 6   │ 1634   │ 5035   │ 4820    │
# │ 7   │ 1635   │ 5106   │ 4928    │
# │ 8   │ 1636   │ 4917   │ 4605    │
# │ 9   │ 1637   │ 4703   │ 4457    │
# │ 10  │ 1638   │ 5359   │ 4952    │
# ⋮
# │ 72  │ 1700   │ 7578   │ 7061    │
# │ 73  │ 1701   │ 8102   │ 7514    │
# │ 74  │ 1702   │ 8031   │ 7656    │
# │ 75  │ 1703   │ 7765   │ 7683    │
# │ 76  │ 1704   │ 6113   │ 5738    │
# │ 77  │ 1705   │ 8366   │ 7779    │
# │ 78  │ 1706   │ 7952   │ 7417    │
# │ 79  │ 1707   │ 8379   │ 7687    │
# │ 80  │ 1708   │ 8239   │ 7623    │
# │ 81  │ 1709   │ 7840   │ 7380    │
# │ 82  │ 1710   │ 7640   │ 7288    │

# %%
stack(births, [:Males, :Females])
# Out:
# 164×3 DataFrame
# │ Row │ variable │ value  │ Year   │
# │     │ Symbol   │ Int64⍰ │ Int64⍰ │
# ├─────┼──────────┼────────┼────────┤
# │ 1   │ Males    │ 5218   │ 1629   │
# │ 2   │ Males    │ 4858   │ 1630   │
# │ 3   │ Males    │ 4422   │ 1631   │
# │ 4   │ Males    │ 4994   │ 1632   │
# │ 5   │ Males    │ 5158   │ 1633   │
# │ 6   │ Males    │ 5035   │ 1634   │
# │ 7   │ Males    │ 5106   │ 1635   │
# │ 8   │ Males    │ 4917   │ 1636   │
# │ 9   │ Males    │ 4703   │ 1637   │
# │ 10  │ Males    │ 5359   │ 1638   │
# ⋮
# │ 154 │ Females  │ 7061   │ 1700   │
# │ 155 │ Females  │ 7514   │ 1701   │
# │ 156 │ Females  │ 7656   │ 1702   │
# │ 157 │ Females  │ 7683   │ 1703   │
# │ 158 │ Females  │ 5738   │ 1704   │
# │ 159 │ Females  │ 7779   │ 1705   │
# │ 160 │ Females  │ 7417   │ 1706   │
# │ 161 │ Females  │ 7687   │ 1707   │
# │ 162 │ Females  │ 7623   │ 1708   │
# │ 163 │ Females  │ 7380   │ 1709   │
# │ 164 │ Females  │ 7288   │ 1710   │

# %%
using Gadfly

# %%
plot(stack(births, [:Males, :Females]), x=:Year, y=:value, color=:variable, Geom.line)
